# %%
import plotly
plotly.__version__
# Out:
# '2.0.7'

# %%
import pandas as pd
df = pd.read_csv('IMLS.csv',encoding='iso-8859-1',sep=',')
df.head()
# Out:
#           LogNumber                                  Institution  \
# 0  IA-00-00-0001-00                      Museum of the Aleutians
# 1  IA-00-00-0002-00                           Depot Museum, Inc.
# 2  IA-00-00-0003-00  National Voting Rights Museum and Institute
# 3  IA-00-00-0005-00           Coronado Museum of History and Art
# 4  IA-00-00-0006-00      Hayward Area Historical  Society Museum
#
#                          Program ProgramType ProjectTitle ProjectType  \
# 0  Conservation Assessment Prog.          IA          NaN         NaN
# 1  Conservation Assessment Prog.          IA          NaN         NaN
# 2  Conservation Assessment Prog.          IA          NaN         NaN
# 3  Conservation Assessment Prog.          IA          NaN         NaN
# 4  Conservation Assessment Prog.          IA          NaN         NaN
#
#    AwardDate           InstAddr1 InstAddr2 InstAddr3     ...       Longitude  \
# 0  3/30/2000        P.O. Box 648       NaN       NaN     ...     -166.536862
# 1  3/30/2000     P.O. Box 681420       NaN       NaN     ...      -85.694757
# 2  3/30/2000   6 Highway 80 East       NaN       NaN     ...      -87.017024
# 3  3/30/2000  1100 Orange Avenue       NaN       NaN     ...     -117.170703
# 4  3/30/2000   22701 Main Street       NaN       NaN     ...     -122.089393
#
#   FIPSState FIPSCounty  CensusTract  CensusBlock  FIPSMCDCode  FIPSPlaceCode  \
# 0       2.0       16.0        200.0       2014.0       1615.0        80770.0
# 1       1.0       49.0     961000.0       2013.0      91206.0        27616.0
# 2       1.0       47.0     957200.0       1005.0      92883.0            NaN
# 3       6.0       73.0      10900.0       1021.0      92780.0        16378.0
# 4       6.0        1.0     435400.0       3003.0      91260.0        33000.0
#
#    CBSACode MetroDivisionCode Description
# 0       NaN               NaN         NaN
# 1       NaN               NaN         NaN
# 2   42820.0               NaN         NaN
# 3   41740.0               NaN         NaN
# 4   41860.0             36084         NaN
#
# [5 rows x 43 columns]

# %%
import plotly.plotly as py

df['text'] = df['Institution'] + '<br>Award ' + (df['AwardTotal']).astype(str)+' dollar'
limits = [(1000,5000),(5000,10000),(10000,100000),(100000,1000000),(1000000,10000000)]
colors = ["rgb(0,201,87)","rgb(0,116,217)","rgb(255,255,0)","rgb(255,128,0)","rgb(255,65,54)"]
cities = []
 
for i in range(0,3):
    lim = limits[i]
    df_sub=df[((df['AwardTotal'])>lim[0])&((df['AwardTotal'])<=lim[1])]
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_sub['Longitude'],
        lat = df_sub['Latitude'],
        text = df_sub['text'],
        marker = dict(
            size = df_sub['AwardTotal']/500,
            color = colors[i],
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        ),
         name ='{0} - {1}'.format(limits[i][0],limits[i][1])+'  US dollar' )
        
    cities.append(city)
for i in range(3,len(limits)):
    lim = limits[i]
    df_sub=df[((df['AwardTotal'])>lim[0])&((df['AwardTotal'])<=lim[1])]
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_sub['Longitude'],
        lat = df_sub['Latitude'],
        text = df_sub['text'],
        marker = dict(
            size = df_sub['AwardTotal']/5500,
            color = colors[i],
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        ),
         name ='{0} - {1}'.format(limits[i][0],limits[i][1])+'  US dollar' )
        
    cities.append(city)

layout = dict(
        title = 'Awards Amount and Awarded Institutions Distribution(1996-2003)<br>(Click legend to toggle traces)',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),
    )
plotly.tools.set_credentials_file(username='JinghanTang', api_key='Kzi5kFRGzdFAQEvHsIN0')
fig = dict( data=cities, layout=layout )
py.iplot( fig, validate=False, filename='price_amount_distribution' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~JinghanTang/6.embed" height="525px" width="100%"></iframe>

# %%
df['text'] = df['Institution'] + '<br>Award ' + df['ProgramType']
types = [
"IM",
"IC",
"LT",
"LG",
"IA",
"IS",
"LI",
"MA",
"MH",
"ML",
"MN",
"IG",
"RE",
"LE",
"IL",
"MP",
"ST"]
colors = ["rgb(0,201,87)","rgb(188,143,143)","rgb(135 206 235)","rgb(255,0,225)","rgb(61,145,64)","rgb(218,112,205)","rgb(255,235,205)","rgb(135,38,87)","rgb(61,89,171)","rgb(30,144,255)","rgb(189,252,201)","rgb(255,192,203)","rgb(94,38,15)","rgb(255,0,1)","rgb(255,255,0)","rgb(255,128,0)","rgb(163,148,128)"]
cities = []

 
for i in range(len(types)):
    df_sub=df[(df['ProgramType'])==types[i]]
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_sub['Longitude'],
        lat = df_sub['Latitude'],
        text = df_sub['text'],
        marker = dict(
            size = 5,
            color = colors[i],
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        ),
         name ='{0} '.format(types[i]))
        
    cities.append(city)

layout = dict(
        title = '1996-2013 Awards Type and Awarded Institutions Distribution <br>(Click legend to toggle traces)',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),
    )
fig = dict( data=cities, layout=layout )
py.iplot( fig, validate=False, filename='award_type_distribution' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~JinghanTang/8.embed" height="525px" width="100%"></iframe>
